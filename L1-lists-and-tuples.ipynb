# %% [markdown]
# # Lists and Tuples
# <hr style ="border:2.5px solid rgba(179, 48, 133, 0.47)""> </hr>

# %% [markdown]
# <b> maria gellor </b>

# %% [markdown]
# ## creating a list

# %%
numbers = [1, 2, 3, 4, 5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
fruits =["apple", "banana", "cherry"]

# %%
mixed_list = [1, "hello", 3.14, True]
mixed_list
# Out:
# [1, 'hello', 3.14, True]

# %% [markdown]
# ## Indexing

# %%
numbers = [1, 2, 3, 4, 5]

# %%
numbers[2]
# Out:
# 3

# %%
numbers[-3]
# Out:
# 3

# %% [markdown]
# ## Modifying Elements

# %%
fruits = ["apple", "banana", "cherry"]

# %%
fruits[0]  = 'Orange'
fruits
# Out:
# ['Orange', 'banana', 'cherry']

# %%
fruits[-2] = 'Blueberry'
fruits
# Out:
# ['Orange', 'Blueberry', 'cherry']

# %% [markdown]
# ## Adding Elements

# %%
fruits = ["apple", "banana", "cherry"]

# %%
fruits.append('orange')
fruits
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'orange', 'orange']

# %%
fruits.insert(1,'Blueberry')
fruits
# Out:
# ['apple', 'Blueberry', 'banana', 'cherry', 'orange', 'orange', 'orange']

# %% [markdown]
# ## Removing Element

# %%
fruits = ["apple", "banana", "cherry"]

# %%
"apple" in fruits
# Out:
# False

# %%
fruits.remove('apple')
fruits
# Out:
# ['banana', 'cherry']

# %%
fruits.pop(0)
fruits
# Out:
# ['cherry']

# %% [markdown]
# ## Sort and Sorted

# %%
numbers = [2,3,4,1,5,9]
numbers
# Out:
# [2, 3, 4, 1, 5, 9]

# %%
numbers.sort()
numbers
# Out:
# [1, 2, 3, 4, 5, 9]

# %%
sorted(numbers)
# Out:
# [1, 2, 3, 4, 5, 9]

# %%
numbers.sort(reverse=True)
numbers
# Out:
# [9, 5, 4, 3, 2, 1]

# %% [markdown]
# ## Slicing

# %%
numbers = [2,3,4,1,5,3,1,6,9]
numbers
# Out:
# [2, 3, 4, 1, 5, 3, 1, 6, 9]

# %%
len(numbers)
# Out:
# 9

# %%
sub = numbers[5:9]
sub
# Out:
# [3, 1, 6, 9]

# %%
numbers[0:9:2]
# Out:
# [2, 4, 5, 1, 9]

# %% [markdown]
# ## Tuple

# %%
my_tuple = (1,2,3,4,5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
type(my_tuple)
# Out:
# tuple

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[1:3]
# Out:
# (2, 3)

# %%
my_tuple[1] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 my_tuple[1] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_tuple = (1,1,2,3,4,5)
my_tuple
# Out:
# (1, 1, 2, 3, 4, 5)
